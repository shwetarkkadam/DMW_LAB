# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %%
df = pd.read_csv("../Datasets/Stationery.csv")

# %%
df.head()
# Out:
#    ID    Name     Item1      Item2      Item3  Item4  Bill
# 0   1  Tushar    Pencil     Eraser   Sharpner    NaN    20
# 1   2  Ramesh       Pen      Pages      Files    Gum    65
# 2   3  Pankaj    Eraser    Perfume  Chocolate    NaN    40
# 3   4  Kartik     Pages      Files    Stapler  Scale   110
# 4   5  Ganesh  Biscuits  Chocolate        NaN    NaN    15

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Item1     0
# Item2     2
# Item3     6
# Item4    16
# Bill      0
# dtype: int64

# %%
df1 = df[['Item1','Item2','Item3','Item4']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      23 non-null     int64
#  1   Name    23 non-null     object
#  2   Item1   23 non-null     object
#  3   Item2   21 non-null     object
#  4   Item3   17 non-null     object
#  5   Item4   7 non-null      object
#  6   Bill    23 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 1.4+ KB

# %%
df1.head()
# Out:
#       Item1      Item2      Item3  Item4
# 0    Pencil     Eraser   Sharpner    NaN
# 1       Pen      Pages      Files    Gum
# 2    Eraser    Perfume  Chocolate    NaN
# 3     Pages      Files    Stapler  Scale
# 4  Biscuits  Chocolate        NaN    NaN

# %%
records = []
for i in range(23):
    records.append([str(df1.values[i, j]) for j in range(0, 4)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 58 Relation derived.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'Eraser', 'Sharpner'})
# frozenset({'Files', 'Stapler'})
# frozenset({'Gum', 'Scale'})
# frozenset({'Gum', 'Sheets'})
# frozenset({'Pages', 'Stapler'})
# frozenset({'Pencil', 'Sharpner'})
# frozenset({'Scale', 'Stapler'})
# frozenset({'Chocolate', 'Biscuits', 'Pencil'})
# frozenset({'Chocolate', 'Biscuits', 'Scale'})
# frozenset({'Chocolate', 'Biscuits', 'nan'})
# frozenset({'Files', 'Chocolate', 'Compass'})
# frozenset({'Chocolate', 'Perfume', 'Eraser'})
# frozenset({'Files', 'Compass', 'Pages'})
# frozenset({'Pen', 'Files', 'Compass'})
# frozenset({'Gum', 'Scale', 'Compass'})
# frozenset({'Gum', 'Compass', 'Sheets'})
# frozenset({'Scale', 'Compass', 'Sheets'})
# frozenset({'Pencil', 'Eraser', 'Pen'})
# frozenset({'Sharpner', 'Eraser', 'Pen'})
# frozenset({'Pencil', 'Eraser', 'Sharpner'})
# frozenset({'Perfume', 'nan', 'Eraser'})
# frozenset({'nan', 'Eraser', 'Sharpner'})
# frozenset({'Gum', 'Files', 'Pages'})
# frozenset({'Gum', 'Files', 'Pen'})
# frozenset({'Gum', 'Files', 'Scale'})
# frozenset({'Gum', 'Files', 'nan'})
# frozenset({'Files', 'Pen', 'Pages'})
# frozenset({'Files', 'Pencil', 'Pages'})
# frozenset({'Files', 'Scale', 'Pages'})
# frozenset({'Files', 'Stapler', 'Pages'})
# frozenset({'Files', 'Scale', 'Stapler'})
# frozenset({'Gum', 'Pages', 'Pen'})
# frozenset({'Gum', 'Scale', 'Sheets'})
# frozenset({'Gum', 'nan', 'Scale'})
# frozenset({'Pages', 'Perfume', 'Notebook'})
# frozenset({'nan', 'Pen', 'Notebook'})
# frozenset({'nan', 'Sheets', 'Notebook'})
# frozenset({'Pages', 'Perfume', 'nan'})
# frozenset({'Pages', 'Scale', 'Stapler'})
# frozenset({'Pencil', 'Scale', 'Pen'})
# frozenset({'Sharpner', 'Pencil', 'Pen'})
# frozenset({'nan', 'Pencil', 'Sharpner'})
# frozenset({'nan', 'Chocolate', 'Biscuits', 'Pencil'})
# frozenset({'Chocolate', 'Biscuits', 'nan', 'Scale'})
# frozenset({'Pen', 'Files', 'Chocolate', 'Compass'})
# frozenset({'Chocolate', 'Perfume', 'nan', 'Eraser'})
# frozenset({'Chocolate', 'nan', 'Pen', 'Notebook'})
# frozenset({'Files', 'nan', 'Compass', 'Pages'})
# frozenset({'Gum', 'Scale', 'Compass', 'Sheets'})
# frozenset({'Sharpner', 'Pencil', 'Eraser', 'Pen'})
# frozenset({'nan', 'Pencil', 'Eraser', 'Sharpner'})
# frozenset({'Gum', 'Files', 'Pen', 'Pages'})
# frozenset({'Gum', 'Files', 'nan', 'Scale'})
# frozenset({'Files', 'Pencil', 'Pen', 'Pages'})
# frozenset({'Files', 'Scale', 'Stapler', 'Pages'})
# frozenset({'Pages', 'Perfume', 'nan', 'Notebook'})
# frozenset({'nan', 'Pencil', 'Pen', 'Notebook'})
# frozenset({'nan', 'Pencil', 'Scale', 'Pen'})

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Eraser -> Sharpner
# Support: 0.13043478260869565
# Confidence: 0.75
# Lift: 5.75
# =====================================
# Rule: Files -> Stapler
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Gum -> Scale
# Support: 0.08695652173913043
# Confidence: 0.6666666666666666
# Lift: 3.0666666666666664
# =====================================
# Rule: Gum -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pencil -> Sharpner
# Support: 0.13043478260869565
# Confidence: 0.42857142857142855
# Lift: 3.2857142857142856
# =====================================
# Rule: Scale -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Chocolate -> Biscuits
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Chocolate -> Biscuits
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Chocolate -> Biscuits
# Support: 0.21739130434782608
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Files -> Chocolate
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Chocolate -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Files -> Compass
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Pen -> Files
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Gum -> Scale
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Gum -> Compass
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Scale -> Compass
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pencil -> Eraser
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Pencil -> Eraser
# Support: 0.13043478260869565
# Confidence: 0.75
# Lift: 5.75
# =====================================
# Rule: Perfume -> nan
# Support: 0.043478260869565216
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: nan -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Gum -> Files
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Gum -> Files
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Gum -> Files
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Gum -> Files
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Files -> Pen
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Files -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Files -> Scale
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Files -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Files -> Scale
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Gum -> Pages
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Gum -> Scale
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Gum -> nan
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pages -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: nan -> Pen
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 3.8333333333333335
# =====================================
# Rule: nan -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Pages -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Pages -> Scale
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pencil -> Scale
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Sharpner -> Pencil
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: nan -> Pencil
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: nan -> Chocolate
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Chocolate -> Biscuits
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pen -> Files
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Chocolate -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Chocolate -> nan
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Files -> nan
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Gum -> Scale
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Pencil
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: nan -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Gum -> Files
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Gum -> Files
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Files -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Files -> Scale
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Pages -> Perfume
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: nan -> Pencil
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 7.666666666666667
# =====================================
# Rule: nan -> Pencil
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 5.75
# =====================================
